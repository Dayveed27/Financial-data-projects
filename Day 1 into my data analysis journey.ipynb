# %%
print ('hello david')
# Out:
# hello david

# %%
name = 'david'
age = 22
height = 1.75

# %%
print(name)
print(age)
print(height)
# Out:
# david
# 22
# 1.75

# %%
print(type(name))
print(type(age))
print(type(height))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>

# %%
age = 22
print(age + 5)
# Out:
# 27

# %%
age = "22"
print(age + "5")
# Out:
# 225

# %%
#Exercises

# %%
name = 'David'
course = 'Statistics'
graduation_year = '2026'
CGPA = 3.56
Whether_i_love_statistics = True

# %%
print(type(name))
print(type(course))
print(type(graduation_year))
print(type(Whether_i_love_statistics))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'bool'>

# %%
CGPA = '3.56'
CGPA_float = float(CGPA) + 0.25
print(CGPA_float)
# Out:
# 3.81

# %%
name = 'David'
course = 'statistics'
print(name + ' is studying ' + course)
# Out:
# David is studying statistics

# %%
graduation_year = '2026'
print(f'i will graduate in {graduation_year}')
# Out:
# i will graduate in 2026

# %%
name = 'David'
course = "statistics"
print(f"{name} is studying {course}")
# Out:
# David is studying statistics

# %%
name = "David"
course = "statistics"
graduation_year = 2026
CGPA = "3.56"
Whether_i_like_statistics = True

# %%
print(f"my name is {name}")
print(f"I am studying {course}")
print(f" I will graduate in {graduation_year}")
print(f" my CGPA is {float(CGPA + 0.25)}")
print(f"do i love statistics {Whether_i_like_statistics}")
# Out:
# my name is David
# I am studying statistics
#  I will graduate in 2026
#  my CGPA is 3.81
# do i love statistics True
